# %% [markdown]
# <a href="https://colab.research.google.com/github/vmr1532/kaggle-projects/blob/master/titanicop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth
auth.authenticate_user()
drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])
filename = "/root/.kaggle/kaggle.json"
if not os.path.exists(os.path.dirname(filename)):
  os.makedirs(os.path.dirname(filename))
request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Download 100%.

# %%
# !pip install kaggle

# %%
# !kaggle competitions download -c titanic

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# ...
#   0% 0.00/59.8k [00:00<?, ?B/s]
# 100% 59.8k/59.8k [00:00<00:00, 51.4MB/s]
# ...
#   0% 0.00/28.0k [00:00<?, ?B/s]
# 100% 28.0k/28.0k [00:00<00:00, 26.8MB/s]
# ...
#   0% 0.00/3.18k [00:00<?, ?B/s]
# 100% 3.18k/3.18k [00:00<00:00, 2.61MB/s]
#      <input type="file" id="files-0cbc328c-eda4-4a75-b9aa-b8ca1eb8fd49" name="files[]" multiple disabled />
#      <output id="result-0cbc328c-eda4-4a75-b9aa-b8ca1eb8fd49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import csv
import numpy
import pandas
train1=pandas.read_csv("train.csv")
test1=pandas.read_csv("test.csv")
print(test1.shape)
print(train1)
import sys
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import sklearn
# Out:
# (418, 11)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
def convert(data):
    number = preprocessing.LabelEncoder()
    data['Names'] = number.fit_transform(data.Names)
    data['train1'] = number.fit_transform(data.train1)
    data=data.fillna(-999)
    


train = pandas.get_dummies(train1, columns=['Embarked','Sex','Name','Cabin','Ticket'])


X = numpy.asarray(train.drop('Survived',axis=1))
yhat = numpy.asarray(train['Survived'])
# Generate random indices for creating a random validation set with 20% of the labelled data
validx = (numpy.random.uniform(size=len(X)) <= 0.2)

# Create training set (80% of the labelled data)
X_trn = X[~validx]
y_trn = yhat[~validx]

# Create validation set (20% of the labelled data)
X_val = X[validx]
y_val = yhat[validx]
test = pandas.get_dummies(test1, columns=['Embarked','Sex','Name','Cabin','Ticket'])
# Create the test set
X_tes = numpy.asarray(test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Flatten
import keras,numpy
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
model=Sequential()
model.add(Flatten()) 
model.add(Dense(128,activation='relu',input_shape=(868,)))
model.add(Dense(10,activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adam(),metrics=['accuracy'])
y=model.fit(numpy.expand_dims(X_trn,axis=3),keras.utils.to_categorical(y_trn, num_classes=10, dtype='int'), epochs=300, batch_size=128,verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
# Epoch 1/300
# 715/715 [==============================] - 1s 901us/step - loss: nan - acc: 0.5427
# Epoch 2/300
# 715/715 [==============================] - 0s 71us/step - loss: nan - acc: 0.6196
# Epoch 3/300
# 715/715 [==============================] - 0s 73us/step - loss: nan - acc: 0.6196
# Epoch 4/300
# 715/715 [==============================] - 0s 68us/step - loss: nan - acc: 0.6196
# Epoch 5/300
# 715/715 [==============================] - 0s 75us/step - loss: nan - acc: 0.6196
# Epoch 6/300
# 715/715 [==============================] - 0s 69us/step - loss: nan - acc: 0.6196
# Epoch 7/300
# 715/715 [==============================] - 0s 66us/step - loss: nan - acc: 0.6196
# Epoch 8/300
# 715/715 [==============================] - 0s 68us/step - loss: nan - acc: 0.6196
# Epoch 9/300
# ...

# %%
import numpy as np
predictions = np.array( [X_tes,]) 
output = np.argmax(predictions,axis=1)
print(output)
print(predictions)
# Out:
# [[417   0  10 188 342 152   8   0   1   1   0 392 345  57 251   8 307  78
#   306 210 214 320 204 295 190 386 387 379 154 174 226  19  17 325 202 237
#    87 198  86 118 143 326 178 258 339 156  94  62 400 158 346  80 375 128
#    63  28  98 166 126 175 356 275 113 106  48  66  37 310   7 388 224 366
#   343 135 313 403 123  82 168  96  14 119  59  46 266 241 115 252 272 328
#   396 207 181 179 399   6 222  56 334  43  65  77 377  49 148 125 305 234
#    27 291 201 141  92 147   9 187 330  58 212 354  32 209  83 338 285 352
#    60 134 293 374 184 239  79 138 194 247 331 155 220 172  90 150 337 329
#   112 228 277 340 211  22 282 381 102 289 167  53  69 271 286  41 404 397
#   401  74 402 368 393 370 348  42 140 139 131 350  93 315 309 373 364 308
#   215  39 169 412 385 353 146 238 378   4  52 229 248 105 268  13 213 243
#    10  18 372  31 319 103 299 244  33  11 318 355 223 195 246  40  35  16
#    75   0 124 245  85 249 121  44 376 394 165 263 153 321 324 149  84 183
# ...
